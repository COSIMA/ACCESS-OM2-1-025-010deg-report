# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import IPython.display
import cmocean as cm
import cartopy.crs as ccrs
import cartopy.feature as cft

import sys, os
sys.path.append(os.path.join(os.getcwd(), '..'))  # so we can import ../exptdata
import exptdata
print('Available exptdata keys: ', [k for k in exptdata.exptdict.keys()])
# Out:
# netcdf_index loaded.
# /home/157/amh157/.local/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):
# Available exptdata keys:  ['1deg', '025deg', '01deg']

# %%
figdir = ''
def savefigure(fname):
    plt.savefig(os.path.join(figdir, fname+'.png'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    plt.savefig(os.path.join(figdir, fname+'.pdf'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    return

# %%
cc.start_cluster()
# Out:
# If the link to the dashboard below doesn't work, run this command on a local terminal to set up a SSH tunnel:
#
#   ssh -N -L 40263:127.0.0.1:40263 vdi-n7.nci.org.au -l amh157
# <Client: scheduler='tcp://127.0.0.1:39926' processes=4 cores=8>

# %%
ekey='1deg'
expt = exptdata.exptdict[ekey]['expt']
n_files = exptdata.exptdict[ekey]['n_files']
time_units = exptdata.exptdict[ekey]['time_units']
offset = exptdata.exptdict[ekey]['offset']

surface_temp_10 = cc.get_nc_variable(expt, 'ocean.nc', 'temp',
                        chunks={'st_ocean': None}, n=n_files,
                        time_units=time_units, offset=offset).isel(st_ocean=0).mean('time')
temp_WOA13_10 = cc.get_nc_variable('woa13/10', 'woa13_ts_??_mom10.nc', 'temp').isel(ZT=0).mean('time')
temp_anom_10 = surface_temp_10 - temp_WOA13_10.values - 273.15
temp_anom_10.load()

IPython.display.clear_output()

temp_anom_10.plot()

# %%
ekey='025deg'
expt = exptdata.exptdict[ekey]['expt']
n_files = exptdata.exptdict[ekey]['n_files']
time_units = exptdata.exptdict[ekey]['time_units']
offset = exptdata.exptdict[ekey]['offset']
surface_temp_025 = cc.get_nc_variable(expt, 'ocean.nc', 'temp',
                        chunks={'st_ocean': None}, n=n_files,
                        time_units=time_units, offset=offset).isel(st_ocean=0).mean('time')
temp_WOA13_025 = cc.get_nc_variable('woa13/025_KDS50', 'woa13_ts_??_mom025.nc', 'temp').isel(ZT=0).mean('time')
temp_anom_025 = surface_temp_025 - temp_WOA13_025.values - 273.15

temp_anom_025.load()

IPython.display.clear_output()

temp_anom_025.plot()

# %%
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
n_files = exptdata.exptdict[ekey]['n_files']
time_units = exptdata.exptdict[ekey]['time_units']
offset = exptdata.exptdict[ekey]['offset']
surface_temp_01 = cc.get_nc_variable(expt, 'ocean.nc', 'temp',
                        chunks={'st_ocean': None}, n=-12,
                        time_units=time_units, offset=offset).isel(st_ocean=0).mean('time')
temp_WOA13_01 = cc.get_nc_variable('woa13/01', 'woa13_ts_??_mom01.nc', 'temp').isel(ZT=0).mean('time')
temp_anom_01 = surface_temp_01 - temp_WOA13_01.values - 273.15
temp_anom_01.load()
IPython.display.clear_output()

temp_anom_01.plot()

# %%
plt.figure(figsize=(8,12))
clev = np.arange(-3,3.01,0.1)
land_50m = cft.NaturalEarthFeature('physical', 'land', '50m',
                                        edgecolor='face',
                                        facecolor='gray')

ax1 = plt.subplot(3,1,1,projection=ccrs.Robinson(central_longitude=-100))
ax1.coastlines(resolution='50m')
ax1.add_feature(land_50m)
p1 = temp_anom_10.plot.pcolormesh(cmap=cm.cm.balance,vmin=-3, vmax=3,add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(a) ACCESS-OM2')

plt.subplot(312)
ax2 = plt.subplot(3,1,2,projection=ccrs.Robinson(central_longitude=-100))
ax2.coastlines(resolution='50m')
ax2.add_feature(land_50m)
p1 = temp_anom_025.plot.pcolormesh(cmap=cm.cm.balance,vmin=-3, vmax=3,add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(b) ACCESS-OM2-025')

ax3 = plt.subplot(3,1,3,projection=ccrs.Robinson(central_longitude=-100))
ax3.coastlines(resolution='50m')
ax3.add_feature(land_50m)
p1 = temp_anom_01.plot.pcolormesh(cmap=cm.cm.balance,vmin=-3, vmax=3,add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(c) ACCESS-OM2-01')

ax4 = plt.axes([0.92,0.35,0.02,0.3])
cb = plt.colorbar(p1,cax=ax4,orientation='vertical')
cb.ax.set_ylabel('SST bias (°C)')
savefigure('global_sst_bias')
